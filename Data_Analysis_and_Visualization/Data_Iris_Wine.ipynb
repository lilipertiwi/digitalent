# %%
import matplotlib.pyplot as plt

import pandas as pd

# %%
#membaca file sekaligus memberi nama kolom, karena iris.csv tidak memiliki nama pada setiap kolom
iris = pd.read_csv('iris.csv', names=['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class'])
print(iris.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
iris.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           class
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
iris.sepal_length.head()
# Out:
# 0    5.1
# 1    4.9
# 2    4.7
# 3    4.6
# 4    5.0
# Name: sepal_length, dtype: float64

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal_length    150 non-null float64
# sepal_width     150 non-null float64
# petal_length    150 non-null float64
# petal_width     150 non-null float64
# class           150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
wine = pd.read_csv('wine.csv', index_col = 0)
wine.head()
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# ...

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150930 entries, 0 to 150929
# Data columns (total 10 columns):
# country        150925 non-null object
# description    150930 non-null object
# designation    105195 non-null object
# points         150930 non-null int64
# price          137235 non-null float64
# province       150925 non-null object
# region_1       125870 non-null object
# region_2       60953 non-null object
# variety        150930 non-null object
# winery         150930 non-null object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 12.7+ MB

# %%
wine.columns
# Out:
# Index(['country', 'description', 'designation', 'points', 'price', 'province',
#        'region_1', 'region_2', 'variety', 'winery'],
#       dtype='object')

# %%
wine.describe()
# Out:
#               points          price
# count  150930.000000  137235.000000
# mean       87.888418      33.131482
# std         3.222392      36.322536
# min        80.000000       4.000000
# 25%        86.000000      16.000000
# 50%        88.000000      24.000000
# 75%        90.000000      40.000000
# max       100.000000    2300.000000

# %%
fig, ax = plt.subplots()
ax.scatter(iris['sepal_length'], iris['sepal_width'])
ax.set_title('Iris Dataset')
ax.set_xlabel('sepal_length')
ax.set_ylabel('sepal_width')
# Out:
# Text(0, 0.5, 'sepal_width')

# %%
#create color dictionary
colors={'Iris-setosa':'r', 'Iris-versicolor':'g', 'Iris-virginica':'b'}
# create a figure and axis
fig, ax = plt.subplots()
# plot each data-point
for i in range(len(iris['sepal_length'])):
    ax.scatter(iris['sepal_length'][i], iris['sepal_width'][i],color=colors[iris['class'][i]])	
# set a title and labels
ax.set_title('Iris Dataset')
ax.set_xlabel('sepal_length')
ax.set_ylabel('sepal_width')
# Out:
# Text(0, 0.5, 'sepal_width')

# %%
columns = iris.columns.drop(['class'])
x_data = range(0,iris.shape[0])

# %%
fig, ax = plt.subplots()
for column in columns:
    ax.plot(x_data, iris[column])
ax.set_title('Iris')
# Out:
# Text(0.5, 1.0, 'Iris')

# %%
data_histogram = wine.points.value_counts()
data_histogram
# Out:
# 87     20747
# 88     17871
# 90     15973
# 86     15573
# 89     12921
# 85     12411
# 84     10708
# 91     10536
# 92      9241
# 83      6048
# 93      6017
# 82      4041
# 94      3462
# 95      1716
# 81      1502
# 80       898
# 96       695
# 97       365
# 98       131
# 99        50
# 100       24
# Name: points, dtype: int64

# %%
#	create	a	figure	and	axis
fig, ax = plt.subplots()
#	count	the	occurrence	of	each	class
data = wine['points'].value_counts()
#	get	x	and	y	data
points = data.index
frequency = data.values
#	create	bar	char
ax.hist(wine.points)
#	create	bar	char
ax.set_title('Wine Review Score')
ax.set_xlabel('Points')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
fig, ax = plt.subplots()
data = wine['points'].value_counts()
points = data.index
frequency = data.values
ax.bar(points, frequency)
ax.set_title('Wine Review Score')
ax.set_xlabel('Points')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#Using Pandas
wine.points.plot.hist()

# %%
linedata = iris.drop(['class'], axis=1)
linedata.plot.hist(subplots=True, layout=(2,2), figsize=(10,10), bins=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001DC1A839C88>,
# ...
#       dtype=object)

# %%
linedata = iris.drop(['class'], axis=1)
linedata.plot.line(title='Iris Dataset')
plt.show()

# %%
wine.points.value_counts().sort_index().plot.bar()
plt.show(block=False)

# %%
wine.points.value_counts().sort_index().plot.barh()
plt.show(block=False)

# %%
#pandas = data langsung diberi method
#seaborn = menggunakan function seaborn
import seaborn as sns
sns.scatterplot(iris.sepal_width, iris.sepal_length)

# %%
sns.distplot(iris.sepal_length, hist=False)
# Out:
# C:\Users\Public\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# regression plot
sns.regplot(x='sepal_length', y='sepal_width', data=iris)

# %%
sns.regplot(x="points", y="price", data=wine)

# %%
sns.lmplot(x='sepal_length', y='sepal_width', data=iris)

# %%
sns.lmplot(x="sepal_length", y="sepal_width", hue="class", data=iris)

# %%
fig, ax = plt.subplots()
ax.scatter(iris['sepal_length'], iris['sepal_width'], iris['petal_length'], iris['petal_length'])

# %%
wine.describe()
# Out:
#               points          price
# count  150930.000000  137235.000000
# mean       87.888418      33.131482
# std         3.222392      36.322536
# min        80.000000       4.000000
# 25%        86.000000      16.000000
# 50%        88.000000      24.000000
# 75%        90.000000      40.000000
# max       100.000000    2300.000000

# %%
#wine.points.value_counts().sort_index().plot.line()
wine.points.value_counts().sort_index().plot.bar() #plot.barh() untuk bar horizontal

# %%
pd.isnull(wine)
# Out:
#         country  description  designation  points  price  province  region_1  \
# 0         False        False        False   False  False     False     False
# 1         False        False        False   False  False     False     False
# 2         False        False        False   False  False     False     False
# 3         False        False        False   False  False     False     False
# 4         False        False        False   False  False     False     False
# 5         False        False        False   False  False     False     False
# 6         False        False        False   False  False     False     False
# 7         False        False        False   False  False     False     False
# 8         False        False        False   False  False     False     False
# 9         False        False        False   False  False     False     False
# 10        False        False        False   False  False     False     False
# ...

# %%
pd.isnull(wine.region_1).sum()
# Out:
# 25060

# %%
wine[pd.isnull(wine.country)]
# Out:
#        country                                        description  \
# 1133       NaN  Delicate white flowers and a spin of lemon pee...
# 1440       NaN  A blend of 60% Syrah, 30% Cabernet Sauvignon a...
# 68226      NaN  From first sniff to last, the nose never makes...
# 113016     NaN  From first sniff to last, the nose never makes...
# 135696     NaN  From first sniff to last, the nose never makes...
#
#          designation  points  price province region_1 region_2     variety  \
# 1133       Askitikos      90   17.0      NaN      NaN      NaN   Assyrtiko
# 1440            Shah      90   30.0      NaN      NaN      NaN   Red Blend
# 68226   Piedra Feliz      81   15.0      NaN      NaN      NaN  Pinot Noir
# 113016  Piedra Feliz      81   15.0      NaN      NaN      NaN  Pinot Noir
# 135696  Piedra Feliz      81   15.0      NaN      NaN      NaN  Pinot Noir
#
#            winery
# 1133     Tsililis
# 1440    Büyülübağ
# 68226     Chilcas
# 113016    Chilcas
# 135696    Chilcas

# %%
wine[pd.isnull(wine.region_1)]
# Out:
#              country                                        description  \
# 25       New Zealand  Yields were down in 2015, but intensity is up,...
# 30          Bulgaria  This Bulgarian Mavrud presents the nose with s...
# 42                US  This is an aromatic brooder with aromas of sco...
# 64          Portugal  This is a super-ripe, still very young wine. I...
# 74          Portugal  It is the ripe dark Alicante Bouschet that dom...
# 81            Israel  Dark red violet in color, this wine has aromas...
# 91          Portugal  The local Baga grape, better known for produci...
# 94          Portugal  This family-owned estate has produced an immed...
# 110         Portugal  This state-owned estate of forests and vineyar...
# 114     South Africa  Muted aromas of tart gooseberry and lime peel ...
# 118           France  This softly fruity wine has the lightest of ta...
# 119         Portugal  This broad, fruity wine brings out ripe berry ...
# ...

# %%
wine[['points', 'price', 'country']].plot.hist(subplots=True,layout=(2,2),figsize=(20,10),bins=20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3e59c13e514f> in <module>
# ----> 1 wine[['points', 'price', 'country']].plot.hist(subplots=True,layout=(2,2),figsize=(20,10),bins=20)
#
# NameError: name 'wine' is not defined

# %%
wine[['points', 'price', 'country']]
# Out:
#         points  price      country
# 0           96  235.0           US
# 1           96  110.0        Spain
# 2           96   90.0           US
# 3           96   65.0           US
# 4           95   66.0       France
# 5           95   73.0        Spain
# 6           95   65.0        Spain
# 7           95  110.0        Spain
# 8           95   65.0           US
# 9           95   60.0           US
# 10          95   80.0        Italy
# 11          95   48.0           US
# 12          95   48.0           US
# 13          95   90.0       France
# 14          95  185.0           US
# 15          95   90.0           US
# 16          95  325.0           US
# 17          95   80.0        Spain
# 18          95  290.0       France
# 19          95   75.0           US
# 20          95   24.0           US
# 21          95   79.0        Spain
# 22          95  220.0        Spain
# 23          95   60.0           US
# 24          95   45.0           US
# 25          94   57.0  New Zealand
# ...

# %%
wine[pd.isnull(wine.points)]
# Out:
# Empty DataFrame
# Columns: [country, description, designation, points, price, province, region_1, region_2, variety, winery]
# Index: []

# %%
reg_1 = wine[wine['country'].isnull()][['country']]
reg_1
# Out:
#        country
# 1133       NaN
# 1440       NaN
# 68226      NaN
# 113016     NaN
# 135696     NaN

# %%
wine['country'].count()
# Out:
# 150925

# %%
ln = wine[['price','points','country']]
ln.plot.hist(subplots=True, layout=(5,2), figsize=(10,10), bins=40)

# %%
fig, ax = plt.subplots()
data = wine['country'].value_counts()
points = data.index
frequency = data.values
ax.bar(points, frequency)
ax.set_title('Wine Country')
ax.set_xlabel('Country')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
wine['country'].unique()
# Out:
# array(['US', 'Spain', 'France', 'Italy', 'New Zealand', 'Bulgaria',
#        'Argentina', 'Australia', 'Portugal', 'Israel', 'South Africa',
#        'Greece', 'Chile', 'Morocco', 'Romania', 'Germany', 'Canada',
#        'Moldova', 'Hungary', 'Austria', 'Croatia', 'Slovenia', nan,
#        'India', 'Turkey', 'Macedonia', 'Lebanon', 'Serbia', 'Uruguay',
#        'Switzerland', 'Albania', 'Bosnia and Herzegovina', 'Brazil',
#        'Cyprus', 'Lithuania', 'Japan', 'China', 'South Korea', 'Ukraine',
#        'England', 'Mexico', 'Georgia', 'Montenegro', 'Luxembourg',
#        'Slovakia', 'Czech Republic', 'Egypt', 'Tunisia', 'US-France'],
#       dtype=object)

# %%
wine.price.plot.hist()

# %%
wine.country.value_counts().sort_index().plot.bar()
plt.show(block=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e11adf925e2e> in <module>
# ----> 1 wine.country.value_counts().sort_index().plot.bar()
#       2 plt.show(block=False)
#
# NameError: name 'wine' is not defined

# %%
iris['class'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
iris[iris['class']=='Iris-setosa'].shape
# Out:
# (50, 5)

# %%
iris['class']=='Iris-setosa'
# Out:
# 12.5

# %%
iris[iris['class']=='Iris-setosa'].shape
