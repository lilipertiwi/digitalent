# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import seaborn as sns

# %%
#membaca file
#df merupakan variabel bertipe dataframe
df = pd.read_csv("Salaries.csv")

# %%
#print first 5 lines
df.head()
# Out:
#    Unnamed: 0      rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0           1      Prof          B             19           18  Male  139750
# 1           2      Prof          B             20           16  Male  173200
# 2           3  AsstProf          B              4            3  Male   79750
# 3           4      Prof          B             45           39  Male  115000
# 4           5      Prof          B             40           41  Male  141500

# %%
#untuk membaca 10 baris pertama
df.head(10)
# Out:
#    Unnamed: 0       rank discipline  yrs.since.phd  yrs.service     sex  \
# 0           1       Prof          B             19           18    Male
# 1           2       Prof          B             20           16    Male
# 2           3   AsstProf          B              4            3    Male
# 3           4       Prof          B             45           39    Male
# 4           5       Prof          B             40           41    Male
# 5           6  AssocProf          B              6            6    Male
# 6           7       Prof          B             30           23    Male
# 7           8       Prof          B             45           45    Male
# 8           9       Prof          B             21           20    Male
# 9          10       Prof          B             18           18  Female
#
#    salary
# 0  139750
# 1  173200
# 2   79750
# 3  115000
# 4  141500
# 5   97000
# 6  175000
# 7  147765
# 8  119250
# 9  129000

# %%
#membaca 5 baris terakhir
df.tail()
# Out:
#      Unnamed: 0      rank discipline  yrs.since.phd  yrs.service   sex  salary
# 392         393      Prof          A             33           30  Male  103106
# 393         394      Prof          A             31           19  Male  150564
# 394         395      Prof          A             42           25  Male  101738
# 395         396      Prof          A             25           15  Male   95329
# 396         397  AsstProf          A              8            4  Male   81035

# %%
#Check a particular column type
df['salary'].dtype
# Out:
# dtype('int64')

# %%
df['rank'].dtype # O = object
# Out:
# dtype('O')

# %%
#Check types for all the columns
df.dtypes
# Out:
# Unnamed: 0        int64
# rank             object
# discipline       object
# yrs.since.phd     int64
# yrs.service       int64
# sex              object
# salary            int64
# dtype: object

# %%
#menampilkan title seluruh kolom
df.columns
# Out:
# Index(['Unnamed: 0', 'rank', 'discipline', 'yrs.since.phd', 'yrs.service',
#        'sex', 'salary'],
#       dtype='object')

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=397, step=1),
#  Index(['Unnamed: 0', 'rank', 'discipline', 'yrs.since.phd', 'yrs.service',
#         'sex', 'salary'],
#        dtype='object')]

# %%
#tipe dimensi, tabel df bertipe 2 dimensi
df.ndim
# Out:
# 2

# %%
#ukuran tabel (baris x kolom)
df.size
# Out:
# 2779

# %%
#menampilkan jumlah baris dan kolom
df.shape
# Out:
# (397, 7)

# %%
#representasi numpy pada data
df.values
# Out:
# array([[1, 'Prof', 'B', ..., 18, 'Male', 139750],
#        [2, 'Prof', 'B', ..., 16, 'Male', 173200],
#        [3, 'AsstProf', 'B', ..., 3, 'Male', 79750],
#        ...,
#        [395, 'Prof', 'A', ..., 25, 'Male', 101738],
#        [396, 'Prof', 'A', ..., 15, 'Male', 95329],
#        [397, 'AsstProf', 'A', ..., 4, 'Male', 81035]], dtype=object)

# %%
#menampilkan statistik dari kolom bernilai numerik
df.describe()
# Out:
#        Unnamed: 0  yrs.since.phd  yrs.service         salary
# count  397.000000     397.000000   397.000000     397.000000
# mean   199.000000      22.314861    17.614610  113706.458438
# std    114.748275      12.887003    13.006024   30289.038695
# min      1.000000       1.000000     0.000000   57800.000000
# 25%    100.000000      12.000000     7.000000   91000.000000
# 50%    199.000000      21.000000    16.000000  107300.000000
# 75%    298.000000      32.000000    27.000000  134185.000000
# max    397.000000      56.000000    60.000000  231545.000000

# %%
#menampilkan nilai maksimal
df.max()
# Out:
# Unnamed: 0          397
# rank               Prof
# discipline            B
# yrs.since.phd        56
# yrs.service          60
# sex                Male
# salary           231545
# dtype: object

# %%
#menampilkan nilai minimal
df.min()
# Out:
# Unnamed: 0               1
# rank             AssocProf
# discipline               A
# yrs.since.phd            1
# yrs.service              0
# sex                 Female
# salary               57800
# dtype: object

# %%
#menampilkan mean
df.mean()
# Out:
# Unnamed: 0          199.000000
# yrs.since.phd        22.314861
# yrs.service          17.614610
# salary           113706.458438
# dtype: float64

# %%
#menampilkan median
df.median()
# Out:
# Unnamed: 0          199.0
# yrs.since.phd        21.0
# yrs.service          16.0
# salary           107300.0
# dtype: float64

# %%
#standar deviasi = rentang/keragaman
#semakin besar standar deviasi maka rentang nilainya semakin jauh
df.std()
# Out:
# Unnamed: 0         114.748275
# yrs.since.phd       12.887003
# yrs.service         13.006024
# salary           30289.038695
# dtype: float64

# %%
#menampilkan record secara random
df.sample(5)
# Out:
#      Unnamed: 0       rank discipline  yrs.since.phd  yrs.service   sex  \
# 44           45       Prof          B             19           19  Male
# 131         132       Prof          A             56           57  Male
# 156         157  AssocProf          B             12           18  Male
# 190         191       Prof          B             22            9  Male
# 138         139  AssocProf          A             10            7  Male
#
#      salary
# 44    94384
# 131   76840
# 156  113341
# 190  180000
# 138   73877

# %%
#menampilkan seluruh record yang tidak memiliki missing value
df.dropna()
# Out:
#      Unnamed: 0       rank discipline  yrs.since.phd  yrs.service     sex  \
# 0             1       Prof          B             19           18    Male
# 1             2       Prof          B             20           16    Male
# 2             3   AsstProf          B              4            3    Male
# 3             4       Prof          B             45           39    Male
# 4             5       Prof          B             40           41    Male
# 5             6  AssocProf          B              6            6    Male
# 6             7       Prof          B             30           23    Male
# 7             8       Prof          B             45           45    Male
# 8             9       Prof          B             21           20    Male
# 9            10       Prof          B             18           18  Female
# 10           11  AssocProf          B             12            8    Male
# 11           12   AsstProf          B              7            2    Male
# ...

# %%
#25% = 25%  orang bekerja <= 7 thn
df['yrs.service'].describe()
# Out:
# count    397.000000
# mean      17.614610
# std       13.006024
# min        0.000000
# 25%        7.000000
# 50%       16.000000
# 75%       27.000000
# max       60.000000
# Name: yrs.service, dtype: float64

# %%
#menghitung nilai mean dari 50 baris pertama
df.head(50).mean()
# Out:
# Unnamed: 0           25.50
# yrs.since.phd        20.92
# yrs.service          16.22
# salary           112625.64
# dtype: float64

# %%
df['salary'].describe()
# Out:
# count       397.000000
# mean     113706.458438
# std       30289.038695
# min       57800.000000
# 25%       91000.000000
# 50%      107300.000000
# 75%      134185.000000
# max      231545.000000
# Name: salary, dtype: float64

# %%
#menghitung banyak value di kolom 'salary'
df['salary'].count()
# Out:
# 397

# %%
#menampilkan berapa macam rank
df['rank'].unique()
# Out:
# array(['Prof', 'AsstProf', 'AssocProf'], dtype=object)

# %%
df['salary'].mean()
# Out:
# 113706.45843828715

# %%
df['salary'].head(50).mean()
# Out:
# 112625.64

# %%
df['salary'].tail(50).mean()
# Out:
# 118160.88

# %%
#mengambil satu kolom secara keseluruhan
df['yrs.service'] #atau >> df.salary
# Out:
# 0      18
# 1      16
# 2       3
# 3      39
# 4      41
# 5       6
# 6      23
# 7      45
# 8      20
# 9      18
# 10      8
# 11      2
# 12      1
# 13      0
# 14     18
# 15      3
# 16     20
# 17     34
# 18     23
# 19     36
# 20     26
# 21     31
# 22     30
# 23     19
# 24      8
# 25      8
# 26     23
# 27      3
# 28      0
# 29      8
#        ..
# 367     1
# 368    30
# 369    31
# 370     8
# 371    20
# 372     7
# 373    26
# 374    19
# 375    26
# 376     1
# 377     3
# 378    38
# 379     8
# 380     3
# 381    23
# 382     5
# 383    44
# 384    21
# 385     9
# 386    27
# 387    15
# 388    36
# 389    18
# 390    19
# 391    19
# 392    30
# 393    19
# 394    25
# 395    15
# 396     4
# Name: yrs.service, Length: 397, dtype: int64

# %%
#Group data using rank
df_rank = df.groupby(['rank'])

# %%
#Calculate mean value for each numeric column per each group
df_rank.mean()
# Out:
#            Unnamed: 0  yrs.since.phd  yrs.service         salary
# rank
# AssocProf  179.828125      15.453125    11.953125   93876.437500
# AsstProf   169.761194       5.104478     2.373134   80775.985075
# Prof       210.977444      28.300752    22.815789  126772.109023

# %%
#Calculate mean salary for each professor rank:
df.groupby('rank')[['salary']].mean()
# Out:
#                   salary
# rank
# AssocProf   93876.437500
# AsstProf    80775.985075
# Prof       126772.109023

# %%
#Calculate mean salary for each professor rank:
df.groupby('rank')['salary'].mean()
# Out:
# rank
# AssocProf     93876.437500
# AsstProf      80775.985075
# Prof         126772.109023
# Name: salary, dtype: float64

# %%
df_rank.std()
# Out:
#            Unnamed: 0  yrs.since.phd  yrs.service        salary
# rank
# AssocProf  102.792217       9.652584    10.100180  13831.699844
# AsstProf   112.097372       2.541381     1.495811   8174.112637
# Prof       116.557830      10.108830    11.590493  27718.674999

# %%
df_rank.max()
# Out:
#            Unnamed: 0 discipline  yrs.since.phd  yrs.service   sex  salary
# rank
# AssocProf         383          B             49           53  Male  126431
# AsstProf          397          B             11            6  Male   97032
# Prof              396          B             56           60  Male  231545

# %%
df_rank['yrs.service','salary'].mean()
# Out:
#            yrs.service         salary
# rank
# AssocProf    11.953125   93876.437500
# AsstProf      2.373134   80775.985075
# Prof         22.815789  126772.109023

# %%
df_rank['yrs.service','salary'].max()
# Out:
#            yrs.service  salary
# rank
# AssocProf           53  126431
# AsstProf             6   97032
# Prof                60  231545

# %%
df_rank['yrs.service','salary'].std()
# Out:
#            yrs.service        salary
# rank
# AssocProf    10.100180  13831.699844
# AsstProf      1.495811   8174.112637
# Prof         11.590493  27718.674999

# %%
#groupby otomatis melakukan pengurutan kolom pertama
#proses sorting memakan waktu, maka jika tidak diperlukan bisa diset sb

#Calculate mean salary for each professor rank:
df.groupby(['rank'], sort=False)[['salary']].mean()
# Out:
#                   salary
# rank
# Prof       126772.109023
# AsstProf    80775.985075
# AssocProf   93876.437500

# %%
df.groupby(['rank'], sort=False).min()
# Out:
#            Unnamed: 0 discipline  yrs.since.phd  yrs.service     sex  salary
# rank
# Prof                1          A             11            0  Female   57800
# AsstProf            3          A              1            0  Female   63100
# AssocProf           6          A              6            1  Female   62884

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'rank', 'discipline', 'yrs.since.phd', 'yrs.service',
#        'sex', 'salary'],
#       dtype='object')

# %%
df_f = df.groupby(['salary'])

# %%
df.groupby(['sex','rank'])[['salary']].mean()
# Out:
#                          salary
# sex    rank
# Female AssocProf   88512.800000
#        AsstProf    78049.909091
#        Prof       121967.611111
# Male   AssocProf   94869.703704
#        AsstProf    81311.464286
#        Prof       127120.822581

# %%
df.groupby(['rank','sex'])[['salary']].mean()
# Out:
#                          salary
# rank      sex
# AssocProf Female   88512.800000
#           Male     94869.703704
# AsstProf  Female   78049.909091
#           Male     81311.464286
# Prof      Female  121967.611111
#           Male    127120.822581

# %%
df.groupby(['sex','rank'])[['salary','yrs.service']].mean()
# Out:
#                          salary  yrs.service
# sex    rank
# Female AssocProf   88512.800000    11.500000
#        AsstProf    78049.909091     2.545455
#        Prof       121967.611111    17.111111
# Male   AssocProf   94869.703704    12.037037
#        AsstProf    81311.464286     2.339286
#        Prof       127120.822581    23.229839

# %%
#Select rows by their position:
df[10:20]
# Out:
#     Unnamed: 0       rank discipline  yrs.since.phd  yrs.service     sex  \
# 10          11  AssocProf          B             12            8    Male
# 11          12   AsstProf          B              7            2    Male
# 12          13   AsstProf          B              1            1    Male
# 13          14   AsstProf          B              2            0    Male
# 14          15       Prof          B             20           18    Male
# 15          16       Prof          B             12            3    Male
# 16          17       Prof          B             19           20    Male
# 17          18       Prof          A             38           34    Male
# 18          19       Prof          A             37           23    Male
# 19          20       Prof          A             39           36  Female
#
#     salary
# 10  119800
# 11   79800
# 12   77700
# 13   78000
# 14  104800
# 15  117150
# 16  101000
# 17  103450
# 18  124750
# 19  137000

# %%
#Calculate mean salary for each professor rank:
df_sub = df[ df['salary'] > 120000 ]

# %%
df_sub
# Out:
#      Unnamed: 0  rank discipline  yrs.since.phd  yrs.service     sex  salary
# 0             1  Prof          B             19           18    Male  139750
# 1             2  Prof          B             20           16    Male  173200
# 4             5  Prof          B             40           41    Male  141500
# 6             7  Prof          B             30           23    Male  175000
# 7             8  Prof          B             45           45    Male  147765
# 9            10  Prof          B             18           18  Female  129000
# 18           19  Prof          A             37           23    Male  124750
# 19           20  Prof          A             39           36  Female  137000
# 26           27  Prof          A             35           23    Male  134885
# 30           31  Prof          B             20            4    Male  132261
# 36           37  Prof          B             22           21    Male  155750
# ...

# %%
df_f = df[ df['sex'] == 'Female']

# %%
df_f.count()
# Out:
# Unnamed: 0       39
# rank             39
# discipline       39
# yrs.since.phd    39
# yrs.service      39
# sex              39
# salary           39
# dtype: int64

# %%
df['salary'] #menampilkan series
df[['salary']] #menampilkan dataframe
# Out:
#      salary
# 0    139750
# 1    173200
# 2     79750
# 3    115000
# 4    141500
# 5     97000
# 6    175000
# 7    147765
# 8    119250
# 9    129000
# 10   119800
# 11    79800
# 12    77700
# 13    78000
# 14   104800
# 15   117150
# 16   101000
# 17   103450
# 18   124750
# 19   137000
# 20    89565
# 21   102580
# 22    93904
# 23   113068
# 24    74830
# 25   106294
# 26   134885
# 27    82379
# 28    77000
# 29   118223
# ..      ...
# 367  108413
# 368  131950
# 369  134690
# 370   78182
# 371  110515
# 372  109707
# 373  136660
# 374  103275
# 375  103649
# 376   74856
# 377   77081
# 378  150680
# 379  104121
# 380   75996
# 381  172505
# 382   86895
# 383  105000
# 384  125192
# 385  114330
# 386  139219
# 387  109305
# 388  119450
# 389  186023
# 390  166605
# 391  151292
# 392  103106
# 393  150564
# 394  101738
# 395   95329
# 396   81035
#
# [397 rows x 1 columns]

# %%
type(df[['salary']])
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['salary'])
# Out:
# pandas.core.series.Series

# %%
df[10:20]
# Out:
#     Unnamed: 0       rank discipline  yrs.since.phd  yrs.service     sex  \
# 10          11  AssocProf          B             12            8    Male
# 11          12   AsstProf          B              7            2    Male
# 12          13   AsstProf          B              1            1    Male
# 13          14   AsstProf          B              2            0    Male
# 14          15       Prof          B             20           18    Male
# 15          16       Prof          B             12            3    Male
# 16          17       Prof          B             19           20    Male
# 17          18       Prof          A             38           34    Male
# 18          19       Prof          A             37           23    Male
# 19          20       Prof          A             39           36  Female
#
#     salary
# 10  119800
# 11   79800
# 12   77700
# 13   78000
# 14  104800
# 15  117150
# 16  101000
# 17  103450
# 18  124750
# 19  137000

# %%
df.loc[10:20,['rank', 'sex', 'salary']]
# Out:
#          rank     sex  salary
# 10  AssocProf    Male  119800
# 11   AsstProf    Male   79800
# 12   AsstProf    Male   77700
# 13   AsstProf    Male   78000
# 14       Prof    Male  104800
# 15       Prof    Male  117150
# 16       Prof    Male  101000
# 17       Prof    Male  103450
# 18       Prof    Male  124750
# 19       Prof  Female  137000
# 20       Prof    Male   89565

# %%
df.loc[10:20,['rank','discipline']]
# Out:
#          rank discipline
# 10  AssocProf          B
# 11   AsstProf          B
# 12   AsstProf          B
# 13   AsstProf          B
# 14       Prof          B
# 15       Prof          B
# 16       Prof          B
# 17       Prof          A
# 18       Prof          A
# 19       Prof          A
# 20       Prof          A

# %%
#menampilakn baris ke 5-10 kolom 0 dan 5
df.iloc[5:10,[0,5]]
# Out:
#    Unnamed: 0     sex
# 5           6    Male
# 6           7    Male
# 7           8    Male
# 8           9    Male
# 9          10  Female

# %%
#menampilkan baris 5-10 kolom 1-3
df.iloc[5:10,1:3]
# Out:
#         rank discipline
# 5  AssocProf          B
# 6       Prof          B
# 7       Prof          B
# 8       Prof          B
# 9       Prof          B

# %%
df.iloc
# Out:
# 0      139750
# 1      173200
# 2       79750
# 3      115000
# 4      141500
# 5       97000
# 6      175000
# 7      147765
# 8      119250
# 9      129000
# 10     119800
# 11      79800
# 12      77700
# 13      78000
# 14     104800
# 15     117150
# 16     101000
# 17     103450
# 18     124750
# 19     137000
# 20      89565
# 21     102580
# 22      93904
# 23     113068
# 24      74830
# 25     106294
# 26     134885
# 27      82379
# 28      77000
# 29     118223
#         ...
# 367    108413
# 368    131950
# 369    134690
# 370     78182
# 371    110515
# 372    109707
# 373    136660
# 374    103275
# 375    103649
# 376     74856
# 377     77081
# 378    150680
# 379    104121
# 380     75996
# 381    172505
# 382     86895
# 383    105000
# 384    125192
# 385    114330
# 386    139219
# 387    109305
# 388    119450
# 389    186023
# 390    166605
# 391    151292
# 392    103106
# 393    150564
# 394    101738
# 395     95329
# 396     81035
# ...

# %%
# Create a new data frame from the original sorted by the column Salary
df_sorted = df.sort_values( by ='yrs.service')
df_sorted.head()
# Out:
#      Unnamed: 0      rank discipline  yrs.since.phd  yrs.service     sex  \
# 154         155  AsstProf          B              4            0    Male
# 127         128  AsstProf          A              2            0  Female
# 164         165  AsstProf          B              1            0    Male
# 28           29  AsstProf          B             11            0    Male
# 287         288  AsstProf          A              2            0    Male
#
#      salary
# 154   92000
# 127   72500
# 164   88795
# 28    77000
# 287   85000

# %%
df_sorted = df.sort_values( by =['yrs.service', 'salary'], ascending = [True, False])
df_sorted.head(10)
# Out:
#      Unnamed: 0      rank discipline  yrs.since.phd  yrs.service     sex  \
# 114         115      Prof          A             12            0  Female
# 154         155  AsstProf          B              4            0    Male
# 164         165  AsstProf          B              1            0    Male
# 157         158  AsstProf          B              1            0    Male
# 287         288  AsstProf          A              2            0    Male
# 95           96  AsstProf          B              4            0    Male
# 13           14  AsstProf          B              2            0    Male
# 28           29  AsstProf          B             11            0    Male
# 35           36  AsstProf          B              5            0  Female
# 308         309  AsstProf          A              5            0    Male
#
#      salary
# 114  105000
# 154   92000
# 164   88795
# 157   88000
# 287   85000
# 95    84000
# 13    78000
# 28    77000
# 35    77000
# 308   74000
