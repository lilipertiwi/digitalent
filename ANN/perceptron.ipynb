# %%
run -i plot_sgd_comparison.py
# Out:
# training SGD
# training ASGD
# training Perceptron
# training Passive-Aggressive I
# training Passive-Aggressive II
# training SAG

# %%
# Out:
# ERROR:root:File `'plot_mlp_training_curves.py'` not found.
